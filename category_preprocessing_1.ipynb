# %%
import pandas as pd

file_name = 'upjong_no_261_2021-09-11.csv'
raw = pd.read_csv(file_name, dtype={'종목코드':object})

# 전체 컬럼 조회
pd.options.display.max_columns = None
raw.head()
# Out:
#          종목명      현재가     전일비      등락률     매수호가     매도호가        거래량      거래대금  \
# 0     한국파마 *  78100.0  8600.0  +12.37%  78100.0  78200.0  3588899.0  279786.0
# 1     삼아제약 *  23050.0  1550.0   +7.21%  23000.0  23050.0   226300.0    5151.0
# 2  코스맥스엔비티 *   9210.0   580.0   +6.72%   9200.0   9210.0   191697.0    1733.0
# 3     지엘팜텍 *   1455.0    85.0   +6.20%   1450.0   1455.0  6712248.0    9666.0
# 4    이수앱지스 *  16350.0   950.0   +6.17%  16350.0  16400.0  1619361.0   25924.0
#
#         전일거래량  종목명_전처리    종목코드  level_0       시가총액     시가총액순위     상장주식수  \
# 0    688406.0     한국파마  032300        0  8,518  억원    코스닥 87위  10906701
# 1    219443.0     삼아제약  009300        1  1,468  억원   코스닥 707위   6370000
# 2    127164.0  코스맥스엔비티  222040        2  1,900  억원   코스닥 569위  20628000
# 3  12967049.0     지엘팜텍  204840        3    755  억원  코스닥 1169위  51886844
# 4    492397.0    이수앱지스  086890        4  5,425  억원   코스닥 164위  33182668
#
#         액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)          투자의견l목표주가  \
# 0    500원  l  1주     10906701        37722       0.35%        N/A  l  N/A
# 1  1,000원  l  1주      6370000        77432       1.22%        N/A  l  N/A
# 2    500원  l  1주     20628000       300027       1.45%  4.00매수  l  14,950
# 3    100원  l  1주     51886844       577674       1.11%        N/A  l  N/A
# 4    500원  l  1주     33182668       102147       0.31%        N/A  l  N/A
#
#             52주최고l최저  PERlEPS(2021.06)    추정PERlEPS  PBRlBPS (2021.06)  \
# 0  94,800  l  20,000  169.41배  l  461원  N/A  l  N/A  17.16배  l  4,551원
# 1  23,000  l  14,300     N/A  l  -175원  N/A  l  N/A  0.84배  l  27,352원
# 2   12,900  l  7,000     N/A  l  -449원  N/A  l  N/A   3.33배  l  2,769원
# 3      2,390  l  855      N/A  l  -67원  N/A  l  N/A     5.33배  l  273원
# 4   25,000  l  6,660     N/A  l  -548원  N/A  l  N/A   8.19배  l  1,997원
#
#   배당수익률l2020.12 동일업종 PER 동일업종 등락률  배당수익률 PERlEPS(2020.12) PBRlBPS (2020.12)  \
# 0         0.06%  107.03배   +0.01%    NaN              NaN               NaN
# 1         1.30%  107.03배   +0.01%    NaN              NaN               NaN
# 2           NaN  107.03배   +0.01%    NaN              NaN               NaN
# 3           NaN  107.03배   +0.01%    NaN              NaN               NaN
# 4           NaN  107.03배   +0.01%    NaN              NaN               NaN
#
#   PERlEPS(2021.03) PBRlBPS (2021.03) PERlEPS(2021.05) PBRlBPS (2021.05)  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   배당수익률l2020.11 PERlEPS(2020.06) PBRlBPS (2020.06)
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN

# %%
raw.columns
# Out:
# Index(['종목명', '현재가', '전일비', '등락률', '매수호가', '매도호가', '거래량', '거래대금', '전일거래량',
#        '종목명_전처리', '종목코드', 'level_0', '시가총액', '시가총액순위', '상장주식수', '액면가l매매단위',
#        '외국인한도주식수(A)', '외국인보유주식수(B)', '외국인소진율(B/A)', '투자의견l목표주가', '52주최고l최저',
#        'PERlEPS(2021.06)', '추정PERlEPS', 'PBRlBPS (2021.06)', '배당수익률l2020.12',
#        '동일업종 PER', '동일업종 등락률', '배당수익률', 'PERlEPS(2020.12)',
#        'PBRlBPS (2020.12)', 'PERlEPS(2021.03)', 'PBRlBPS (2021.03)',
#        'PERlEPS(2021.05)', 'PBRlBPS (2021.05)', '배당수익률l2020.11',
#        'PERlEPS(2020.06)', 'PBRlBPS (2020.06)'],
#       dtype='object')

# %%
# 결측치의 비율
raw.isnull().mean() * 100
# Out:
# 종목명                    0.000000
# 현재가                    0.000000
# 전일비                    0.000000
# 등락률                    0.000000
# 매수호가                   0.000000
# 매도호가                   0.000000
# 거래량                    0.000000
# 거래대금                   0.000000
# 전일거래량                  0.000000
# 종목명_전처리                0.000000
# 종목코드                   0.000000
# level_0                0.000000
# 시가총액                   0.000000
# 시가총액순위                 0.000000
# 상장주식수                  0.000000
# 액면가l매매단위               1.342282
# 외국인한도주식수(A)            0.000000
# 외국인보유주식수(B)            0.000000
# 외국인소진율(B/A)            0.000000
# 투자의견l목표주가              0.000000
# 52주최고l최저               0.000000
# PERlEPS(2021.06)       7.382550
# 추정PERlEPS              0.000000
# PBRlBPS (2021.06)      7.382550
# 배당수익률l2020.12         48.993289
# 동일업종 PER               0.000000
# 동일업종 등락률               0.000000
# 배당수익률                100.000000
# PERlEPS(2020.12)      94.630872
# PBRlBPS (2020.12)     94.630872
# PERlEPS(2021.03)      99.328859
# PBRlBPS (2021.03)     99.328859
# PERlEPS(2021.05)      99.328859
# PBRlBPS (2021.05)     99.328859
# 배당수익률l2020.11         99.328859
# PERlEPS(2020.06)      99.328859
# PBRlBPS (2020.06)     99.328859
# dtype: float64

# %%
df = raw.dropna(axis=1, how='all').copy()
df.head()
# Out:
#          종목명      현재가     전일비      등락률     매수호가     매도호가        거래량      거래대금  \
# 0     한국파마 *  78100.0  8600.0  +12.37%  78100.0  78200.0  3588899.0  279786.0
# 1     삼아제약 *  23050.0  1550.0   +7.21%  23000.0  23050.0   226300.0    5151.0
# 2  코스맥스엔비티 *   9210.0   580.0   +6.72%   9200.0   9210.0   191697.0    1733.0
# 3     지엘팜텍 *   1455.0    85.0   +6.20%   1450.0   1455.0  6712248.0    9666.0
# 4    이수앱지스 *  16350.0   950.0   +6.17%  16350.0  16400.0  1619361.0   25924.0
#
#         전일거래량  종목명_전처리    종목코드  level_0       시가총액     시가총액순위     상장주식수  \
# 0    688406.0     한국파마  032300        0  8,518  억원    코스닥 87위  10906701
# 1    219443.0     삼아제약  009300        1  1,468  억원   코스닥 707위   6370000
# 2    127164.0  코스맥스엔비티  222040        2  1,900  억원   코스닥 569위  20628000
# 3  12967049.0     지엘팜텍  204840        3    755  억원  코스닥 1169위  51886844
# 4    492397.0    이수앱지스  086890        4  5,425  억원   코스닥 164위  33182668
#
#         액면가l매매단위  외국인한도주식수(A)  외국인보유주식수(B) 외국인소진율(B/A)          투자의견l목표주가  \
# 0    500원  l  1주     10906701        37722       0.35%        N/A  l  N/A
# 1  1,000원  l  1주      6370000        77432       1.22%        N/A  l  N/A
# 2    500원  l  1주     20628000       300027       1.45%  4.00매수  l  14,950
# 3    100원  l  1주     51886844       577674       1.11%        N/A  l  N/A
# 4    500원  l  1주     33182668       102147       0.31%        N/A  l  N/A
#
#             52주최고l최저  PERlEPS(2021.06)    추정PERlEPS  PBRlBPS (2021.06)  \
# 0  94,800  l  20,000  169.41배  l  461원  N/A  l  N/A  17.16배  l  4,551원
# 1  23,000  l  14,300     N/A  l  -175원  N/A  l  N/A  0.84배  l  27,352원
# 2   12,900  l  7,000     N/A  l  -449원  N/A  l  N/A   3.33배  l  2,769원
# 3      2,390  l  855      N/A  l  -67원  N/A  l  N/A     5.33배  l  273원
# 4   25,000  l  6,660     N/A  l  -548원  N/A  l  N/A   8.19배  l  1,997원
#
#   배당수익률l2020.12 동일업종 PER 동일업종 등락률 PERlEPS(2020.12) PBRlBPS (2020.12)  \
# 0         0.06%  107.03배   +0.01%              NaN               NaN
# 1         1.30%  107.03배   +0.01%              NaN               NaN
# 2           NaN  107.03배   +0.01%              NaN               NaN
# 3           NaN  107.03배   +0.01%              NaN               NaN
# 4           NaN  107.03배   +0.01%              NaN               NaN
#
#   PERlEPS(2021.03) PBRlBPS (2021.03) PERlEPS(2021.05) PBRlBPS (2021.05)  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   배당수익률l2020.11 PERlEPS(2020.06) PBRlBPS (2020.06)
# 0           NaN              NaN               NaN
# 1           NaN              NaN               NaN
# 2           NaN              NaN               NaN
# 3           NaN              NaN               NaN
# 4           NaN              NaN               NaN

# %%
print(raw.shape)
df.shape
# Out:
# (149, 37)
# (149, 36)
